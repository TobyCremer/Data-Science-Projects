# %% [markdown]
# # Exploring the Mad Men Cast Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Loading the Data Set

# %%
cast_data_csv = '../datasets/mad-men-cast-show-data.csv'

# %%
cast = pd.read_csv(cast_data_csv, encoding='iso-8859-1')

# %% [markdown]
# ## Exploratory Data Analysis

# %%
cast.head()
# Out:
#           Performer          Show  Show Start Show End Status?  CharEnd  \
# 0       Steven Hill   Law & Order        1990     2010     END     2000
# 1    Kelli Williams  The Practice        1997     2014     END     2003
# 2  LisaGay Hamilton  The Practice        1997     2014     END     2003
# 3  Lara Flynn Boyle  The Practice        1997     2014     END     2003
# 4   Dylan McDermott  The Practice        1997     2014     END     2004
#
#    Years Since  #LEAD  #SUPPORT  #Shows  Score      Score/Y  \
# 0           15      0         0       0   0.00            0
# 1           12      0         1       6   6.25  0.520833333
# 2           12      2         0       2   4.00  0.333333333
# 3           12      0         0       0   0.00            0
# 4           11      2         7       6   9.75  0.886363636
#
#                                    lead_notes  \
# 0                                         NaN
# 1                                         NaN
# ...

# %%
cast.tail()
# Out:
#            Performer             Show  Show Start Show End Status?  CharEnd  \
# 243     Meghan Wolfe   True Detective        2014  PRESENT    LEFT     2014
# 244       Kevin Dunn   True Detective        2014  PRESENT    LEFT     2014
# 245    Charles Dance  Game of Thrones        2011  PRESENT    LEFT     2015
# 246  Patrick Dempsey   Grey's Anatomy        2005  PRESENT    LEFT     2015
# 247   Ian McElhinney  Game of Thrones        2011  PRESENT    LEFT     2015
#
#      Years Since  #LEAD  #SUPPORT  #Shows  Score  Score/Y lead_notes  \
# 243            1      0         0       0   0.00        0        NaN
# 244            1      0         1       2   2.25     2.25        NaN
# 245            0      0         2       1   1.50  #DIV/0!        NaN
# 246            0      0         0       0   0.00  #DIV/0!        NaN
# 247            0      0         0       0   0.00  #DIV/0!        NaN
#
#                            support_notes                    show_notes
# ...

# %%
cast.dtypes
# Out:
# Performer         object
# Show              object
# Show Start         int64
# Show End          object
# Status?           object
# CharEnd            int64
# Years Since        int64
# #LEAD              int64
# #SUPPORT           int64
# #Shows             int64
# Score            float64
# Score/Y           object
# lead_notes        object
# support_notes     object
# show_notes        object
# dtype: object

# %%
cast.columns.tolist()
# Out:
# ['Performer',
#  'Show',
#  'Show Start',
#  'Show End',
#  'Status?',
#  'CharEnd',
#  'Years Since',
#  '#LEAD',
#  '#SUPPORT',
#  '#Shows',
#  'Score',
#  'Score/Y',
#  'lead_notes',
#  'support_notes',
#  'show_notes']

# %%
'performer',
                     'show',
                     'show_start',
                     'show_end',
                     'status',
                     'char_end',
                     'years_since',
                     'lead',
                     'support',
                     'shows',
                     'score',
                     'score_y',
                     'lead_notes',
                     'support_notes',
                     'show_notes'

# %%
new_column_names = {'Performer':'performer',
                     'Show':'show',
                     'Show Start':'show_start',
                     'Show End':'show_end',
                     'Status?':'status',
                     'CharEnd':'char_end',
                     'Years Since': 'years_since',
                     '#LEAD':'lead',
                     '#SUPPORT':'support',
                     '#Shows':'shows',
                     'Score':'score',
                     'Score/Y':'score_y',
                     'lead_notes':'lead_notes',
                     'support_notes':'support_notes',
                     'show_notes':'show_notes'
                   }

# %%
cast = cast.rename(columns=new_column_names)

# %%
cast.head()
# Out:
#           performer          show  show_start show_end status  char_end  \
# 0       Steven Hill   Law & Order        1990     2010    END      2000
# 1    Kelli Williams  The Practice        1997     2014    END      2003
# 2  LisaGay Hamilton  The Practice        1997     2014    END      2003
# 3  Lara Flynn Boyle  The Practice        1997     2014    END      2003
# 4   Dylan McDermott  The Practice        1997     2014    END      2004
#
#    years_since  lead  support  shows  score      score_y  \
# 0           15     0        0      0   0.00            0
# 1           12     0        1      6   6.25  0.520833333
# 2           12     2        0      2   4.00  0.333333333
# 3           12     0        0      0   0.00            0
# 4           11     2        7      6   9.75  0.886363636
#
#                                    lead_notes  \
# 0                                         NaN
# 1                                         NaN
# ...

# %%
cast.describe().T
# Out:
#              count         mean       std     min      25%     50%     75%  \
# Show Start   248.0  2004.713710  4.985271  1990.0  2003.00  2006.0  2008.0
# CharEnd      248.0  2009.895161  3.331408  2000.0  2006.00  2010.0  2013.0
# Years Since  248.0     5.104839  3.331408     0.0     2.00     5.0     9.0
# #LEAD        248.0     0.673387  1.214861     0.0     0.00     0.0     1.0
# #SUPPORT     248.0     1.560484  2.352613     0.0     0.00     1.0     2.0
# #Shows       248.0     1.729839  2.195781     0.0     0.00     1.0     3.0
# Score        248.0     2.793347  2.931469     0.0     0.25     2.0     4.5
#
#                  max
# Show Start   2014.00
# CharEnd      2015.00
# Years Since    15.00
# #LEAD           8.00
# #SUPPORT       17.00
# #Shows         10.00
# Score          14.25

# %%
cast.isnull().sum()
# Out:
# performer          0
# show               0
# show_start         0
# show_end           0
# status             0
# char_end           0
# years_since        0
# lead               0
# support            0
# shows              0
# score              0
# score_y            0
# lead_notes       159
# support_notes    113
# show_notes       110
# dtype: int64

# %%
cast.shape
# Out:
# (248, 15)

# %%
cast.performer.unique()
# Out:
# array(['Steven Hill', 'Kelli Williams', 'LisaGay Hamilton',
#        'Lara Flynn Boyle', 'Dylan McDermott', 'Camryn Manheim',
#        'Steve Harris', 'Marla Sokoloff', 'Jerry Orbach',
#        'Michael Badalucco', 'Michael C. Hall', 'Joe Mantegna',
#        'Peter Krause', 'Rachel Griffiths', 'Jason Ritter',
#        'Freddy RodrÕguez', 'Frances Conroy', 'Lauren Ambrose',
#        'Amber Tamblyn', 'Justina Machado', 'Mary Steenburgen',
#        'Mathew St. Patrick', 'Michael Welch', 'Aaron Himelstein',
#        'Becky Wahlstrom', 'Chris Marquette', 'Mageina Tovah', 'Rob Lowe',
#        'Dul_ Hill', 'Dayton Callie', 'Timothy Olyphant', 'Joshua Malina',
#        'Anna Gunn', 'Allison Janney', 'Drea de Matteo', 'Paula Malcomson',
#        'Leon Rippy', 'Kim Dickens', 'Bradley Whitford', 'Molly Parker',
#        'William Sanderson', 'Sean Bridgers', 'Richard Schiff',
#        'Ian McShane', 'John Hawkes', 'Robin Weigert', 'Jim Beaver',
# ...

# %%
cast.show.unique()
# Out:
# array(['Law & Order', 'The Practice', 'Six Feet Under', 'Joan of Arcadia',
#        'The West Wing', 'Deadwood', 'The Sopranos', 'Boston Legal', 'ER',
#        'Friday Night Lights', '24', 'Heroes', 'Lost', 'Dexter', 'Damages',
#        'Big Love', 'House', 'Downton Abbey', "Grey's Anatomy", 'Homeland',
#        'Breaking Bad', 'Game of Thrones',
#        'CSI: Crime Scene Investigations', 'Boardwalk Empire',
#        'True Blood', 'True Detective -10', 'True Detective -29',
#        'House of Cards', 'True Detective'], dtype=object)
